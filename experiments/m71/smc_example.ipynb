# %%
import sys
sys.path.append("/home/twhit/smcdet")

from smcdet.sampler import SMCsampler
from smcdet.prior import M71Prior
from smcdet.images import M71ImageModel
from smcdet.kernel import SingleComponentMH
from smcdet.aggregate import Aggregate

import torch

import matplotlib.pyplot as plt

import numpy as np

import pickle

from utils.misc import select_cuda_device

device = select_cuda_device()
torch.cuda.set_device(device)
torch.set_default_device(device)
# Out:
# Selected device 2, which has 10822 MB available.

# %% [markdown]
# We load in the M71 tiles and catalogs:

# %%
tiles = torch.load("data/tiles.pt").to(device)
counts = torch.load("data/pruned_counts_magcut.pt").to(device)
locs = torch.load("data/pruned_locs_magcut.pt").to(device)
fluxes = torch.load("data/pruned_fluxes_magcut.pt").to(device)

# %%
with open('data/params.pkl', 'rb') as f:
    params = pickle.load(f)

params
# Out:
# {'flux_alpha': 0.21411753249015655,
#  'flux_lower': 0.06291294097900389,
#  'flux_upper': 1804.6791992187502,
#  'flux_detection_threshold': 0.25165176391601557,
#  'counts_rate': 0.030264640226960182,
#  'background': 104.1486587524414,
#  'adu_per_nmgy': 240.57542419433594,
#  'psf_params': tensor([1.2269, 2.6466, 5.6672, 7.0683, 0.4634, 0.0884]),
#  'noise_additive': 1.0000007072408224e-10,
#  'noise_multiplicative': 1.9396677017211914}

# %%
fig, ax = plt.subplots(2, 4, figsize = (16, 6))
np.random.seed(0)

for h in range(2):
    for w in range(4):
        idx = np.random.randint(0, tiles.shape[0])
        _ = ax[h,w].imshow(tiles[idx].cpu(), cmap = 'gray')
        tmp = ax[h,w].scatter(locs[idx].squeeze()[:counts[idx].int().squeeze(),1].cpu() - 0.5,
                            locs[idx].squeeze()[:counts[idx].int().squeeze(),0].cpu() - 0.5,
                            c = fluxes[idx].squeeze()[:counts[idx].int().squeeze()].cpu(),
                            marker = '*', edgecolors = 'black', s = 100, cmap = 'Wistia')
        _ = fig.colorbar(tmp, fraction = 0.045)

fig.tight_layout()

# %% [markdown]
# We'll run our SMC algorithm to catalog one of the images:

# %%
idx = 42
_ = plt.imshow(tiles[idx].cpu(), cmap = 'gray')
tmp = plt.scatter(locs[idx].squeeze()[:counts[idx].int().squeeze(),1].cpu() - 0.5,
                locs[idx].squeeze()[:counts[idx].int().squeeze(),0].cpu() - 0.5,
                c = fluxes[idx].squeeze()[:counts[idx].int().squeeze()].cpu(),
                marker = '*', edgecolors = 'black', s = 100, cmap = 'Wistia')
_ = plt.colorbar(tmp, fraction = 0.045)

print(f'Number of stars within image boundary: {counts[idx]}')
print(f'Total intrinsic flux of stars within image boundary: {fluxes[idx].sum(-1)}')
print(f'Total observed flux: {tiles[idx].sum().round()}')
# Out:
# Number of stars within image boundary: 2.0
# Total intrinsic flux of stars within image boundary: 6.132575511932373
# Total observed flux: 10043.0

# %%
tile_dim = 8
pad = 4

TilePrior = M71Prior(min_objects = 10,
                     max_objects = 10,
                     counts_rate = params["counts_rate"],
                     image_height = tile_dim,
                     image_width = tile_dim,
                     flux_alpha = params["flux_alpha"],
                     flux_lower = params["flux_lower"],
                     flux_upper = params["flux_upper"],
                     pad = pad)

TileImageModel = M71ImageModel(image_height = tile_dim,
                               image_width = tile_dim,
                               background = params["background"],
                               adu_per_nmgy = params["adu_per_nmgy"],
                               psf_params = params["psf_params"],
                               noise_additive = params["noise_additive"],
                               noise_multiplicative = params["noise_multiplicative"])

MHKernel = SingleComponentMH(num_iters = 100,
                             locs_stdev = 0.1,
                             fluxes_stdev = 2.5,
                             fluxes_min = TilePrior.flux_lower,
                             fluxes_max = TilePrior.flux_upper)

# %%
torch.manual_seed(0)

sampler = SMCsampler(image = tiles[idx],
                     tile_dim = tile_dim,
                     Prior = TilePrior,
                     ImageModel = TileImageModel,
                     MutationKernel = MHKernel,
                     num_catalogs_per_count = 10000,
                     ess_threshold_prop = 0.5,
                     resample_method = "multinomial",
                     max_smc_iters = 100,
                     print_every = 2)

sampler.run()
# Out:
# starting the tile samplers...
# iteration 2: temperature in [0.01, 0.01], acceptance rate in [0.48, 0.48]
# iteration 4: temperature in [0.02, 0.02], acceptance rate in [0.51, 0.51]
# iteration 6: temperature in [0.07, 0.07], acceptance rate in [0.51, 0.51]
# iteration 8: temperature in [0.15, 0.15], acceptance rate in [0.5, 0.5]
# iteration 10: temperature in [0.33, 0.33], acceptance rate in [0.46, 0.46]
# iteration 12: temperature in [0.64, 0.64], acceptance rate in [0.42, 0.42]
# done!

# %% [markdown]
# Now we instantiate an `Aggregate` object and resample the catalogs we sampled above. The `Aggregate` object isn't doing much work here at all, but it's helpful when we run our procedure on images partitioned into tiles.

# %%
aggMH = SingleComponentMH(num_iters = 50,
                          locs_stdev = 0.1,
                          fluxes_stdev = 2.5,
                          fluxes_min = TilePrior.flux_lower,
                          fluxes_max = TilePrior.flux_upper)

# %%
agg = Aggregate(sampler.Prior,
                sampler.ImageModel,
                aggMH,
                sampler.tiled_image,
                sampler.counts,
                sampler.locs,
                sampler.fluxes,
                sampler.weights_intercount,
                sampler.log_normalizing_constant,
                flux_detection_threshold = params["flux_detection_threshold"],
                ess_threshold_prop = 0.5,
                resample_method = "multinomial")

agg.run()
# Out:
# aggregating tile catalogs...
# done!

# %% [markdown]
# We summarize our results by reporting the posterior distribution over the number of stars within the image boundaries and the posterior mean of the total intrinsic flux:

# %%
agg.summarize()
# Out:
# posterior distribution of number of detectable stars within image boundary:
# tensor([1, 2, 3, 4])
# tensor([0.0150, 0.5550, 0.4170, 0.0130])
#
# posterior mean total intrinsic flux (including undetectable and/or in padding) = 142.19471740722656
#
# posterior mean total intrinsic flux of detectable stars within image boundary = 6.2377519607543945
#
# number of unique catalogs = 6016

# %% [markdown]
# We can examine the posterior predictive distribution of the total observed flux. The dotted black line is the true total observed flux, computed by summing the intensities of all the pixels in the image. We expect

# %%
tmp = plt.hist(agg.posterior_predictive_total_observed_flux.squeeze().cpu(), bins = 50, density = True, color = 'goldenrod')
_ = plt.vlines(x = tiles[idx].sum().cpu(), ymin = 0, ymax = tmp[0].max(), color = 'black', linestyle = 'dotted')

# %% [markdown]
# We can also examine the posterior distribution of the total intrinsic flux of stars within the image boundary. The dotted black line is the ground truth. For images with stars near the boundary, this distribution will be multimodal. For each catalog, the total intrinsic flux within the boundary will depend on the locations of the stars near the boundary. We still expect credible intervals based on this distribution to achieve nominal frequentist coverage in the limit of infinite samples, but some modes may not be characterized well unless the number of samples is large.

# %%
tmp = plt.hist(agg.pruned_fluxes.squeeze().sum(-1).cpu(), bins = 50, density = True, color = 'darkseagreen')
_ = plt.vlines(x = fluxes[idx].sum(-1).cpu(), ymin = 0, ymax = tmp[0].max(), color = 'black', linestyle = 'dotted')

# %% [markdown]
# We can also reconstruct the image using a few of our posterior samples:

# %%
fig, ax = plt.subplots(1, 6, figsize = (20,4))

tmp = ax[0].imshow(tiles[idx].cpu(), cmap = 'gray')
_ = fig.colorbar(tmp, fraction = 0.045)
_ = ax[0].set_title('original image')
_ = ax[0].scatter(locs[idx].squeeze()[:counts[idx].int().squeeze(),1].cpu() - 0.5,
                  locs[idx].squeeze()[:counts[idx].int().squeeze(),0].cpu() - 0.5,
                  c = locs[idx].squeeze()[:counts[idx].int().squeeze(),0].cpu(),
                  vmin = fluxes[idx][fluxes[idx]>0].min().cpu(),
                  vmax = fluxes[idx][fluxes[idx]>0].max().cpu(),
                  cmap = 'Wistia', marker = '*', edgecolors = 'black', s = 100)
_ = ax[0].set_xticks([])
_ = ax[0].set_yticks([])

for j in range(1,6):
    index = torch.randint(low = 0, high = agg.counts.shape[-1] - 1, size = [1])
    psf = agg.ImageModel.psf(agg.locs[:,:,index])
    rate = (psf * agg.ImageModel.adu_per_nmgy * agg.fluxes[:,:,index].unsqueeze(-3).unsqueeze(-4)).sum(-1) + agg.ImageModel.background
    reconstruction = torch.distributions.Normal(rate, (params["noise_additive"] + params["noise_multiplicative"] * rate).sqrt()).sample().squeeze([0,1]).permute((2,0,1))
    tmp = ax[j].imshow(reconstruction[0].cpu(), cmap = 'gray', vmin = tiles[idx].cpu().min(), vmax = tiles[idx].cpu().max())
    _ = ax[j].set_title('posterior sample')
    _ = fig.colorbar(tmp, fraction = 0.045)
    _ = ax[j].scatter(agg.locs.squeeze()[index,:agg.counts.squeeze()[index].int(),1].cpu() - 0.5,
                      agg.locs.squeeze()[index,:agg.counts.squeeze()[index].int(),0].cpu() - 0.5,
                      c = agg.fluxes.squeeze()[index,:agg.counts.squeeze()[index].int()].cpu(),
                      vmin = fluxes[idx][fluxes[idx]>0].min().cpu(),
                      vmax = fluxes[idx][fluxes[idx]>0].max().cpu(),
                      cmap = 'Wistia', marker = '*', edgecolors = 'black', s = 100)
    _ = ax[j].set_xticks([])
    _ = ax[j].set_yticks([])

fig.tight_layout()

# %% [markdown]
# To assess the locations of light sources in our posterior catalogs, we plot a two-dimensional density plot of these locations and overlay them on the image:

# %%
fig, ax = plt.subplots(1, 1, figsize = (6, 6))
_ = ax.imshow(tiles[idx].arcsinh().cpu(), cmap = 'gray')
_ = ax.scatter(agg.locs.squeeze()[...,1].cpu() - 0.5,
               agg.locs.squeeze()[...,0].cpu() - 0.5,
               c = agg.fluxes.squeeze().cpu(),
               vmin = min(fluxes[idx][fluxes[idx]>0].min().cpu(), agg.fluxes.squeeze()[idx][agg.fluxes.squeeze()[idx]>0].quantile(0.05).cpu()),
               vmax = max(fluxes[idx][fluxes[idx]>0].max().cpu(), agg.fluxes.squeeze()[idx][agg.fluxes.squeeze()[idx]>0].quantile(0.95).cpu()),
               marker = '.', cmap = 'Wistia', s = 10, alpha = 0.2)
tmp = ax.scatter(locs[idx].squeeze()[:counts[idx].int(),1].cpu() - 0.5,
               locs[idx].squeeze()[:counts[idx].int(),0].cpu() - 0.5,
               c = fluxes[idx].squeeze()[:counts[idx].int()].cpu(),
               vmin = min(fluxes[idx][fluxes[idx]>0].min().cpu(), agg.fluxes.squeeze()[idx][agg.fluxes.squeeze()[idx]>0].quantile(0.05).cpu()),
               vmax = max(fluxes[idx][fluxes[idx]>0].max().cpu(), agg.fluxes.squeeze()[idx][agg.fluxes.squeeze()[idx]>0].quantile(0.95).cpu()),
               marker = '*', cmap = 'Wistia', edgecolors = 'purple', linewidth = 2, s = 200)
_ = fig.colorbar(tmp, fraction = 0.045)
_ = ax.set_xticks([])
_ = ax.set_yticks([])

# %% [markdown]
# We repeat the above after applying the location and flux thresholds:

# %%
fig, ax = plt.subplots(1, 1, figsize = (6, 6))
_ = ax.imshow(tiles[idx].arcsinh().cpu(), cmap = 'gray')
_ = ax.scatter(agg.pruned_locs.squeeze()[...,1].cpu() - 0.5,
               agg.pruned_locs.squeeze()[...,0].cpu() - 0.5,
               c = agg.pruned_fluxes.squeeze().cpu(),
               vmin = min(fluxes[idx][fluxes[idx]>0].min().cpu(), agg.pruned_fluxes.squeeze()[idx][agg.pruned_fluxes.squeeze()[idx]>0].quantile(0.05).cpu()),
               vmax = max(fluxes[idx][fluxes[idx]>0].max().cpu(), agg.pruned_fluxes.squeeze()[idx][agg.pruned_fluxes.squeeze()[idx]>0].quantile(0.95).cpu()),
               marker = '.', cmap = 'Wistia', s = 10, alpha = 0.2)
tmp = ax.scatter(locs[idx].squeeze()[:counts[idx].int(),1].cpu() - 0.5,
               locs[idx].squeeze()[:counts[idx].int(),0].cpu() - 0.5,
               c = fluxes[idx].squeeze()[:counts[idx].int()].cpu(),
               vmin = min(fluxes[idx][fluxes[idx]>0].min().cpu(), agg.pruned_fluxes.squeeze()[idx][agg.pruned_fluxes.squeeze()[idx]>0].quantile(0.05).cpu()),
               vmax = max(fluxes[idx][fluxes[idx]>0].max().cpu(), agg.pruned_fluxes.squeeze()[idx][agg.pruned_fluxes.squeeze()[idx]>0].quantile(0.95).cpu()),
               marker = '*', cmap = 'Wistia', edgecolors = 'purple', linewidth = 2, s = 200)
_ = fig.colorbar(tmp, fraction = 0.045)
_ = ax.set_xticks([])
_ = ax.set_yticks([])
